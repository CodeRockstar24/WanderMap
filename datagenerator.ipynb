# %%
real_places = [
    # Cities
    'Paris', 'New York', 'Tokyo', 'London', 'Sydney', 'Barcelona', 'Dubai', 'Rome', 'Cape Town', 'Singapore',
    'Bangkok', 'Istanbul', 'Moscow', 'Toronto', 'Los Angeles', 'Buenos Aires', 'Berlin', 'Amsterdam', 'Lisbon', 'Chicago',

    # Beaches & Islands
    'Bora Bora', 'Maldives', 'Maui', 'Santorini', 'Phuket', 'Ibiza', 'Bali', 'Cancun', 'Maui', 'Fiji',

    # Mountains & National Parks
    'Yellowstone', 'Yosemite', 'Banff', 'Swiss Alps', 'Rocky Mountains', 'Mount Fuji', 'Himalayas', 'Patagonia',

    # Historic Sites
    'Machu Picchu', 'Great Wall of China', 'Pyramids of Giza', 'Colosseum', 'Angkor Wat', 'Stonehenge', 'Taj Mahal',

    # Others
    'Grand Canyon', 'Serengeti', 'Galápagos Islands', 'Venice', 'Dubai Desert', 'Amazon Rainforest'
]


place_types = {
    # Cities
    'Paris': 'City', 'New York': 'City', 'Tokyo': 'City', 'London': 'City', 'Sydney': 'City', 'Barcelona': 'City',
    'Dubai': 'City', 'Rome': 'City', 'Cape Town': 'City', 'Singapore': 'City', 'Bangkok': 'City', 'Istanbul': 'City',
    'Moscow': 'City', 'Toronto': 'City', 'Los Angeles': 'City', 'Buenos Aires': 'City', 'Berlin': 'City',
    'Amsterdam': 'City', 'Lisbon': 'City', 'Chicago': 'City',

    # Beaches & Islands
    'Bora Bora': 'Island', 'Maldives': 'Island', 'Maui': 'Island', 'Santorini': 'Island', 'Phuket': 'Beach',
    'Ibiza': 'Beach', 'Bali': 'Island', 'Cancun': 'Beach', 'Fiji': 'Island',

    # Mountains & National Parks
    'Yellowstone': 'National Park', 'Yosemite': 'National Park', 'Banff': 'National Park',
    'Swiss Alps': 'Mountain', 'Rocky Mountains': 'Mountain', 'Mount Fuji': 'Mountain',
    'Himalayas': 'Mountain', 'Patagonia': 'Mountain',

    # Historic Sites
    'Machu Picchu': 'Historic Site', 'Great Wall of China': 'Historic Site', 'Pyramids of Giza': 'Historic Site',
    'Colosseum': 'Historic Site', 'Angkor Wat': 'Historic Site', 'Stonehenge': 'Historic Site', 'Taj Mahal': 'Historic Site',

    # Others
    'Grand Canyon': 'National Park', 'Serengeti': 'National Park', 'Galápagos Islands': 'Island',
    'Venice': 'City', 'Dubai Desert': 'Desert', 'Amazon Rainforest': 'Forest'
}

# %%
import numpy as np
import pandas as pd
import random

np.random.seed(42)
random.seed(42)


real_places = [
    'Paris', 'New York', 'Tokyo', 'London', 'Sydney', 'Barcelona', 'Dubai', 'Rome', 'Cape Town', 'Singapore',
    'Bangkok', 'Istanbul', 'Moscow', 'Toronto', 'Los Angeles', 'Buenos Aires', 'Berlin', 'Amsterdam', 'Lisbon', 'Chicago',
    'Bora Bora', 'Maldives', 'Maui', 'Santorini', 'Phuket', 'Ibiza', 'Bali', 'Cancun', 'Fiji',
    'Yellowstone', 'Yosemite', 'Banff', 'Swiss Alps', 'Rocky Mountains', 'Mount Fuji', 'Himalayas', 'Patagonia',
    'Machu Picchu', 'Great Wall of China', 'Pyramids of Giza', 'Colosseum', 'Angkor Wat', 'Stonehenge', 'Taj Mahal',
    'Grand Canyon', 'Serengeti', 'Galápagos Islands', 'Venice', 'Dubai Desert', 'Amazon Rainforest'
]

place_types = {
    # Cities
    'Paris': 'City', 'New York': 'City', 'Tokyo': 'City', 'London': 'City', 'Sydney': 'City', 'Barcelona': 'City',
    'Dubai': 'City', 'Rome': 'City', 'Cape Town': 'City', 'Singapore': 'City', 'Bangkok': 'City', 'Istanbul': 'City',
    'Moscow': 'City', 'Toronto': 'City', 'Los Angeles': 'City', 'Buenos Aires': 'City', 'Berlin': 'City',
    'Amsterdam': 'City', 'Lisbon': 'City', 'Chicago': 'City',

    # Beaches & Islands
    'Bora Bora': 'Island', 'Maldives': 'Island', 'Maui': 'Island', 'Santorini': 'Island', 'Phuket': 'Beach',
    'Ibiza': 'Beach', 'Bali': 'Island', 'Cancun': 'Beach', 'Fiji': 'Island',

    # Mountains & National Parks
    'Yellowstone': 'National Park', 'Yosemite': 'National Park', 'Banff': 'National Park',
    'Swiss Alps': 'Mountain', 'Rocky Mountains': 'Mountain', 'Mount Fuji': 'Mountain',
    'Himalayas': 'Mountain', 'Patagonia': 'Mountain',

    # Historic Sites
    'Machu Picchu': 'Historic Site', 'Great Wall of China': 'Historic Site', 'Pyramids of Giza': 'Historic Site',
    'Colosseum': 'Historic Site', 'Angkor Wat': 'Historic Site', 'Stonehenge': 'Historic Site', 'Taj Mahal': 'Historic Site',

    # Others
    'Grand Canyon': 'National Park', 'Serengeti': 'National Park', 'Galápagos Islands': 'Island',
    'Venice': 'City', 'Dubai Desert': 'Desert', 'Amazon Rainforest': 'Forest'
}

place_coords = {
    'Paris': (48.8566, 2.3522), 'New York': (40.7128, -74.0060), 'Tokyo': (35.6762, 139.6503),
    'London': (51.5074, -0.1278), 'Sydney': (-33.8688, 151.2093), 'Barcelona': (41.3851, 2.1734),
    'Dubai': (25.2048, 55.2708), 'Rome': (41.9028, 12.4964), 'Cape Town': (-33.9249, 18.4241),
    'Singapore': (1.3521, 103.8198), 'Bangkok': (13.7563, 100.5018), 'Istanbul': (41.0082, 28.9784),
    'Moscow': (55.7558, 37.6173), 'Toronto': (43.6532, -79.3832), 'Los Angeles': (34.0522, -118.2437),
    'Buenos Aires': (-34.6037, -58.3816), 'Berlin': (52.5200, 13.4050), 'Amsterdam': (52.3676, 4.9041),
    'Lisbon': (38.7223, -9.1393), 'Chicago': (41.8781, -87.6298),
    'Bora Bora': (-16.5004, -151.7415), 'Maldives': (3.2028, 73.2207), 'Maui': (20.7984, -156.3319),
    'Santorini': (36.3932, 25.4615), 'Phuket': (7.8804, 98.3923), 'Ibiza': (38.9067, 1.4206),
    'Bali': (-8.3405, 115.0920), 'Cancun': (21.1619, -86.8515), 'Fiji': (-17.7134, 178.0650),
    'Yellowstone': (44.4280, -110.5885), 'Yosemite': (37.8651, -119.5383), 'Banff': (51.1784, -115.5708),
    'Swiss Alps': (46.8876, 9.6570), 'Rocky Mountains': (39.5501, -105.7821), 'Mount Fuji': (35.3606, 138.7274),
    'Himalayas': (27.9878, 86.9250), 'Patagonia': (-49.3310, -72.8762),
    'Machu Picchu': (-13.1631, -72.5450), 'Great Wall of China': (40.4319, 116.5704),
    'Pyramids of Giza': (29.9792, 31.1342), 'Colosseum': (41.8902, 12.4922), 'Angkor Wat': (13.4125, 103.8670),
    'Stonehenge': (51.1789, -1.8262), 'Taj Mahal': (27.1751, 78.0421),
    'Grand Canyon': (36.1069, -112.1129), 'Serengeti': (-2.3333, 34.8333), 'Galápagos Islands': (-0.9538, -90.9656),
    'Venice': (45.4408, 12.3155), 'Dubai Desert': (25.1482, 55.3132), 'Amazon Rainforest': (-3.4653, -62.2159)
}

num_records = 20000
data = []

for i in range(num_records):
    place = random.choice(real_places)
    base_lat, base_lon = place_coords[place]


    lat = round(np.clip(np.random.normal(base_lat, 0.5), -90, 90), 5)
    lon = round(np.clip(np.random.normal(base_lon, 0.5), -180, 180), 5)

    dest_type = place_types[place]

    popularity = np.clip(np.random.beta(2, 5), 0, 1)
    rating = np.clip(np.random.normal(4, 0.5), 1, 5)
    reviews = int(np.clip(popularity * 5000 + np.random.normal(0, 200), 10, 10000))

    climate_map = {
        'Beach': ['Hot', 'Temperate'],
        'Mountain': ['Temperate', 'Cold'],
        'City': ['Hot', 'Temperate', 'Cold'],
        'Historic Site': ['Hot', 'Temperate', 'Cold'],
        'National Park': ['Temperate', 'Cold'],
        'Desert': ['Hot'],
        'Island': ['Hot', 'Temperate'],
        'Forest': ['Temperate', 'Cold'],
        'Lake': ['Temperate', 'Cold']
    }
    climate = random.choice(climate_map.get(dest_type, ['Temperate']))

    accessibility = np.clip(np.random.normal(0.7, 0.15), 0, 1)

    if dest_type in ['City', 'Historic Site']:
        nearby = int(np.clip(np.random.normal(5, 2), 0, 15))
    else:
        nearby = int(np.clip(np.random.normal(2, 1), 0, 8))

    description_templates = [
        f"A {climate.lower()} {dest_type.lower()} known for its {random.choice(['stunning views', 'rich history', 'beautiful beaches', 'vibrant culture', 'tranquil nature'])}.",
        f"Popular destination featuring {random.choice(['friendly locals', 'amazing food', 'unique wildlife', 'scenic trails', 'historic landmarks'])}.",
        f"Famous for its {random.choice(['breathtaking sunsets', 'adventure sports', 'peaceful environment', 'artistic heritage', 'lush landscapes'])}.",
        f"Offers a {random.choice(['perfect getaway', 'memorable vacation', 'unique travel experience', 'family-friendly atmosphere', 'romantic escape'])}."
    ]
    description = random.choice(description_templates)

    data.append({
        'Destination_ID': i+1,
        'Destination_Name': place,
        'Latitude': lat,
        'Longitude': lon,
        'Type': dest_type,
        'Popularity_Score': round(popularity, 3),
        'Average_Rating': round(rating, 2),
        'Number_of_Reviews': reviews,
        'Climate': climate,
        'Accessibility_Score': round(accessibility, 3),
        'Nearby_Attractions_Count': nearby,
        'Description_Text': description
    })

df = pd.DataFrame(data)
df.to_csv('travelreport.csv', index=False)
